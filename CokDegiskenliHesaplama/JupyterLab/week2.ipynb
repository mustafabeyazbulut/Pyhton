# %%
path=r"C:\Users\mustafa\Desktop\picture.jpg"
path
# Out:
# 'C:\\Users\\mustafa\\Desktop\\picture.jpg'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
my_img_01=plt.imread(path)

# %%
plt.imshow(my_img_01) # my_image_01 değişkeninde olan resmi görüntülemek için kullanıyoruz
plt.show()

# %%
my_img_01.shape
# Out:
# (404, 1425, 4)

# %%
im_02=my_img_01[100:200,100:200,:] # resim üzerinde belli bir alanı yeni değişkene atıyoruz.
plt.imshow(im_02) # im_02 değişkeninde olan yeni resmi görüntülemek için kullanıyoruz
plt.show()

# %%
im_02=my_img_01[100:101,100:200,:] # resim üzerinde belli bir alanı yeni değişkene atıyoruz.
plt.imshow(im_02) # im_02 değişkeninde olan yeni resmi görüntülemek için kullanıyoruz
plt.show()

# %%
def add_on_my_gf_2(x,y): # XOR
    if x==0 and y==0:
        return 0
    if x==0 and y==1:
        return 1
    if x==1 and y==0:
        return 1
    if x==1 and y==1:
        return 0
def subs_on_my_gf_2(x,y):
    return add_on_my_gf_2(x,y)
def multiply_on_my_gf_2(x,y):
    if x==0 and y==0:
        return 0
    if x==0 and y==1:
        return 0
    if x==1 and y==0:
        return 0
    if x==1 and y==1:
        return 1

# %%
v_1=0
v_2=0
add_on_my_gf_2(v_1,v_2)
# Out:
# 0

# %%
im_02.shape # vektörün kaç boyutlu olduğunu gösteriyor
# Out:
# (1, 100, 4)

# %%
im_03=im_02[:,:,0]
im_03.shape
# Out:
# (1, 100)

# %%
new_im_03=[]
for i in range (100): 
    if im_03[0,i]<150:
        new_im_03.append(0)
    else:
        new_im_03.append(1)

# %%
for i in new_im_03:
    print(i,add_on_my_gf_2(i,1))

# %%
my_img_01.shape
# Out:
# (404, 1425, 4)

# %%
im_5=my_img_01[:,:,0]

# %%
plt.imshow(im_5,cmap='gray')
plt.show()

# %%
im_5.shape
# Out:
# (404, 1425)

# %%
im_6=np.zeros((404,1425))

# %%
plt.imshow(im_6,cmap='gray')
plt.show()

# %%
for i in range(404):
    for j in range (1425):
        if im_5[i,j]>150:
            im_6[i,j]=1

# %%
for i in range(404):
    for j in range (1425):
        im_6[i,j]=add_on_my_gf_2(im_6[i,j],1)
